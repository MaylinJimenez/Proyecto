# %% [markdown]
# <h1 style = "color:#8c886f; text-align: center; font-weight: bold" >Universidad Castro Carazo </h1>
# <h5 style= "color: #6a9277; text-align: center">Bienes raíces</h5>
# <center> <img src="real-estate.png"></center>
# </br>
# <p style = "text-align:justify; font-family: Tahoma

# %% [markdown]
# <table>
#   <tr>
#     <td><img src="pantone (1).png"> </td>
#     <td>Paleta de Colores</td>
#     <th> <a href= "https://paletadecolores.com.mx/paleta/b7cbbf/8c886f/f9a799/f4bfad/f5dabd/">Enlace al Sitio Web</a> </th>
#   </tr>
# </table>

# %% [markdown]
# <h4 style="color:#7f440a; font-family: Tahoma"> 1.1) Librerias necesarias para trabajar </h4>

# %%
import numpy as np #esta libreria es para trabajar estructuras de datos (listas, tuplas,diccionarios)
import pandas as pd #esta libreria se usa para el manejo de datos (dataFrame)
import matplotlib as mpl #esta libreria se usa para crear graficos
import matplotlib.pyplot as plt #esta libreria se usa para crear graficos 
import seaborn as sn #esta libreria se usa para crear graficos

# %% [markdown]
# <h4 style="color: #7f440a;font-family:Tahoma">1.2) Importar y revisar el Set de Datos </h4>

# %%
cols= ["Serial Number", "List Year", "Date Recorded", "Town", "Address", "Assessed Value",
       "Sale Amount", "Sales Ratio", "Property Type", "Residential Type", "Non Use Code", "Assessor Remarks", "OPM remarks",
       "Location"]
dfpropiedades= pd.read_csv("dataset1.csv",sep=";", names=cols)
print("Se cargaron los datos a la memoria")
dfpropiedades.head()
# Out:
# C:\Users\Maylin Jimenez\AppData\Local\Temp\ipykernel_7580\3940246653.py:4: DtypeWarning: Columns (0,1,5,6,7,8,9,10,11,12,14,15,16,17,19,20,22,23,24,25,27,28,32,33,34,37,38,42,43,47,48,49,52,53,54,57,58,62,63,67,68,72,73,77,78,82,83,87,88,92,93,97,98,99,102,103,107,108,112,113,117,118,122,123,127,128,132,133,138) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfpropiedades= pd.read_csv("dataset1.csv",sep=";", names=cols)
# Se cargaron los datos a la memoria
# ...

# %%
dfpropiedades.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Serial Number  \
# ...

# %%
dfpropiedades1 = dfpropiedades[dfpropiedades.isnull()]
dfpropiedades1.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Serial Number  \
# ...

# %%
dfpropiedades1.tail()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Serial Number  \
# ...

# %%
dfpropiedades1.columns
# Out:
# Index(['Serial Number', 'List Year', 'Date Recorded', 'Town', 'Address',
#        'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type',
#        'Residential Type', 'Non Use Code', 'Assessor Remarks', 'OPM remarks',
#        'Location'],
#       dtype='object')

# %%
dfpropiedades1.rename({'Serial Number':'serial_number', 'List Year':'list_year', 'Date Recorded':'data_recorded', 'Town':'town', 'Address':'address', 
               'Assessed Value':'assesed_value', 'Sale Amount':'sale_amount', 'Sales Ratio':'sales_ratio', 'Property Type':'property_type', 
               'Residential Type':'residential_type', 'Non Use Code':'non_use_code', 'Assessor Remarks':'assessor_remarks', 'OPM remarks':'opm_remarks',
                'Location':'location'},axis=0, inplace=True) #axis=0 es para cambiar solo indices. axis=1 para cambiar columnas
dfpropiedades1.columns
dfpropiedades1.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Serial Number  \
# ...

# %%
dfpropiedades1.reset_index(drop=True, inplace=False)
dfpropiedades1
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Serial Number  \
# ...

# %%
print(dfpropiedades1)
dfpropiedades1.reset_index(drop=True, inplace=True)
print(dfpropiedades1)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Serial Number  \
# ...

# %%
dfpropiedades1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190041 entries, 0 to 190040
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Serial Number     0 non-null      float64
#  1   List Year         0 non-null      float64
#  2   Date Recorded     0 non-null      object
#  3   Town              0 non-null      object
#  4   Address           0 non-null      float64
#  5   Assessed Value    0 non-null      float64
#  6   Sale Amount       0 non-null      float64
#  7   Sales Ratio       0 non-null      object
#  8   Property Type     0 non-null      object
#  9   Residential Type  0 non-null      float64
#  10  Non Use Code      0 non-null      float64
#  11  Assessor Remarks  0 non-null      float64
#  12  OPM remarks       0 non-null      float64
#  13  Location          0 non-null      object
# dtypes: float64(9), object(5)
# memory usage: 20.3+ MB
